# %% [markdown]
# # `word2vec`
# Feature extraction is done via `word2vec`. `word2vec` model is trained from scratch with both labeled and unlabeled train data.
#
# Submission accuracy (average): `0.83104`
# Submission accuracy (clustering): `0.80764`

# %% [markdown]
# Download necessary NLTK files:
# * `stopwords`: Stopwords Corpus
# * `wordnet`: WordNet
# * `punkt`: Punkt Tokenizer Models

# %%
# %%script false
# import nltk
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.donwload('punkt')

# %%
import numpy as np
import pandas as pd
import nltk
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from gensim.models import word2vec
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from os.path import join
from tqdm import tqdm

# %% [markdown]
# Since `word2vec` is unsupervised, we can use the unlabeled training data here.

# %%
src = 'data'
df_labeled_train = pd.read_csv(join(src, 'labeledTrainData.tsv'), sep='\t')
df_unlabeled_train = pd.read_csv(join(src, 'unlabeledTrainData.tsv'), sep='\t', quoting=3)
df_test = pd.read_csv(join(src, 'testData.tsv'), sep='\t')

df_labeled_train.shape, df_unlabeled_train.shape, df_test.shape
# Out:
# ((25000, 3), (50000, 2), (25000, 2))

# %% [markdown]
# ## Data cleaning
# We clean the data similarly to how it was done previously. However, we avoid removing numbers and stop words. We also leave each sentence as a list of words, instead of an entire string.

# %%
stopwords = set(stopwords.words('english'))

def clean_sentence(sentence, remove_stopwords):
    removed_markup = BeautifulSoup(sentence, 'html.parser').get_text()
    removed_punctuation = re.sub(r'[^a-zA-Z0-9]', ' ', removed_markup)
    tokens = removed_punctuation.lower().split()
    if remove_stopwords:
        tokens = [t for t in tokens if t not in stopwords]
    return tokens

# %% [markdown]
# `word2vec` expects single sentences, each one as a list of words. In order to split a paragraph into sentences, we use NLTK's `punkt` tokenizer.

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer

# %%
def review_to_sentences(review, remove_stopwords):
    raw_sentences = tokenizer.tokenize(review.strip())
    return [clean_sentence(sentence, remove_stopwords) for sentence in raw_sentences if len(sentence) > 0]

# %%
sentences = []
[sentences.extend(review_to_sentences(review, remove_stopwords=False)) for review in tqdm(df_labeled_train['review'])]
[sentences.extend(review_to_sentences(review, remove_stopwords=False)) for review in tqdm(df_unlabeled_train['review'])];
# Out:
#   1%|▌                                                                            | 188/25000 [00:00<00:40, 618.39it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#   3%|██▍                                                                          | 807/25000 [00:01<00:39, 613.97it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#   6%|████▋                                                                       | 1550/25000 [00:02<00:39, 598.17it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.happierabroad.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 100%|███████████████████████████████████████████████████████████████████████████| 25000/25000 [00:43<00:00, 571.67it/s]
#   1%|▍                                                                            | 310/50000 [00:00<01:20, 613.91it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
#   5%|███▊                                                                        | 2531/50000 [00:04<01:26, 551.94it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.loosechangeguide.com/LooseChangeGuide.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
#  14%|██████████▉                                                                 | 7187/50000 [00:12<01:16, 556.78it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'... ...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  35%|██████████████████████████▏                                                | 17486/50000 [00:30<00:57, 564.66it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  43%|████████████████████████████████                                           | 21354/50000 [00:37<00:50, 568.89it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.msnbc.msn.com/id/4972055/site/newsweek/"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
#  62%|██████████████████████████████████████████████▊                            | 31182/50000 [00:54<00:32, 571.23it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  72%|█████████████████████████████████████████████████████▉                     | 35974/50000 [01:03<00:24, 568.17it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=a0KSqelmgN8"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
#  88%|██████████████████████████████████████████████████████████████████         | 44054/50000 [01:17<00:10, 566.37it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.. .'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  97%|████████████████████████████████████████████████████████████████████████▋  | 48447/50000 [01:25<00:02, 567.67it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://jake-weird.blogspot.com/2007/08/beneath.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [01:27<00:00, 568.33it/s]

# %% [markdown]
# _Note: Errors are from URLs in the sentences._

# %%
len(sentences)
# Out:
# 795872

# %% [markdown]
# ## Training `word2vec`
# **Parameters**
# `num_features`: The dimension of each word vector
# `min_word_count`: Words that occur fewer than this value across all training samples are ignored. Reasonable values are [10, 100].
# `num_workers`: Parallel processing threads
# `window`: Size of context window
# `downsampling`: Amount of downsampling to use for frequent words. Google documentation recommends [1e-5, 1e-3].

# %%
num_features = 300
min_word_count = 40
num_workers = 4
window = 10
downsampling = 1e-3

# %%
# %%time
model = word2vec.Word2Vec(sentences,
                          size=num_features,
                          window=window,
                          min_count=min_word_count,
                          sample=downsampling)
# Out:
# Wall time: 1min 38s

# %%
# makes the model more memory efficient, but only if not training any further
model.init_sims(replace=True)
model.save(f'model/features{num_features}_minword{min_word_count}_window{window}')

# %% [markdown]
# ## Evaluate model

# %%
model.wv.doesnt_match('france england germany berlin'.split())
# Out:
# d:\program files\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'berlin'

# %%
model.wv.most_similar('man')
# Out:
# d:\program files\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('woman', 0.6391713619232178),
#  ('lady', 0.59377121925354),
#  ('lad', 0.5750746726989746),
#  ('monk', 0.5367291569709778),
#  ('millionaire', 0.5239022970199585),
#  ('farmer', 0.5203163623809814),
#  ('guy', 0.519966721534729),
#  ('person', 0.507594645023346),
#  ('soldier', 0.50559401512146),
#  ('men', 0.4995683431625366)]

# %% [markdown]
# ## Vectorizing paragraphs: averaging
# For all words in each paragraph, we obtain their corresponding word vectors. The vector of the paragraph is then taken to be the average of all its word vectors.

# %%
def compute_sentence_vec(sentence):
    model_vocab = set(model.wv.vocab.keys())
    word_vecs = [model.wv[word] for word in sentence if word in model_vocab]
    if len(word_vecs) > 0:
        feature_vec = np.stack([model.wv[word] for word in sentence if word in model_vocab])
        return np.average(feature_vec, axis=0)
    return np.zeros([model.vector_size])

def compute_review_vec(review):
    feature_vec = np.stack([compute_sentence_vec(sentence) 
                            for sentence in review_to_sentences(review, remove_stopwords=True)
                            if len(sentence) > 0])
    return np.average(feature_vec, axis=0)

# %%
train_vecs = np.stack([compute_review_vec(review) for review in tqdm(df_labeled_train['review'])])
test_vecs = np.stack([compute_review_vec(review) for review in tqdm(df_test['review'])])
train_vecs.shape, test_vecs.shape
# Out:
#   1%|▋                                                                             | 218/25000 [00:03<06:58, 59.20it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#   3%|██▋                                                                           | 866/25000 [00:14<06:53, 58.38it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#   6%|████▉                                                                        | 1585/25000 [00:28<06:56, 56.28it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.happierabroad.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 100%|████████████████████████████████████████████████████████████████████████████| 25000/25000 [08:49<00:00, 47.18it/s]
#  20%|███████████████▌                                                             | 5038/25000 [02:02<08:04, 41.18it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  28%|█████████████████████▋                                                       | 7043/25000 [02:55<07:28, 40.05it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'....................................................................'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 100%|████████████████████████████████████████████████████████████████████████████| 25000/25000 [09:30<00:00, 43.79it/s]
# ((25000, 300), (25000, 300))

# %% [markdown]
# ### Random forest classifier

# %%
# %%time
clf = RandomForestClassifier(n_estimators=100)
clf.fit(train_vecs, df_labeled_train['sentiment'])
# Out:
# Wall time: 55.2 s

# %%
# %%time
pred = clf.predict(test_vecs)
# Out:
# Wall time: 1.07 s

# %%
output = pd.DataFrame({'id': df_test['id'], 'sentiment': pred})
output
# Out:
#              id  sentiment
# 0      12311_10          1
# 1        8348_2          0
# 2        5828_4          1
# 3        7186_2          0
# 4       12128_7          1
# 5        2913_8          0
# 6        4396_1          0
# 7         395_2          0
# 8       10616_1          0
# 9        9074_9          1
# 10       9252_3          1
# 11       9896_9          1
# 12        574_4          0
# 13      11182_8          1
# 14      11656_4          0
# 15       2322_4          1
# 16       8703_1          0
# 17       7483_1          0
# 18      6007_10          1
# 19      12424_4          0
# 20       4672_1          0
# 21      10841_3          1
# 22       8954_7          0
# 23       7392_1          1
# 24      10288_8          1
# 25       5343_4          0
# 26       4950_1          0
# 27       9257_4          0
# 28       8689_3          0
# 29       4480_2          0
# ...         ...        ...
# 24970   6857_10          1
# 24971   11091_8          1
# 24972    4167_2          0
# 24973     679_4          0
# 24974   10147_1          0
# 24975    6875_1          0
# 24976    923_10          1
# 24977    6200_8          0
# 24978    7208_8          1
# 24979    5363_8          1
# 24980    4067_8          0
# 24981    1773_7          1
# 24982   1498_10          1
# 24983  10497_10          1
# 24984   3444_10          1
# 24985     588_2          0
# 24986    9678_9          1
# 24987    1983_9          0
# 24988    5012_3          0
# 24989   12240_2          1
# 24990    5071_2          0
# 24991    5078_2          0
# 24992   10069_3          0
# 24993    7407_8          1
# 24994    7207_1          0
# 24995   2155_10          1
# 24996     59_10          1
# 24997    2531_1          1
# 24998    7772_8          1
# 24999  11465_10          0
#
# [25000 rows x 2 columns]

# %%
output.to_csv('submission/word2vec_avg_randomforest.csv', index=False)

# %% [markdown]
# ## Vectorizing paragraphs: clustering
# The words in the `word2vec` model vocabulary are first clustered. The vector for each paragraph will then be the sum of occurrences of each cluster, based on the words in that paragraph.

# %%
# %%time
word_vectors = model.wv.vectors
n_clusters = word_vectors.shape[0] // 5
clf = KMeans(n_clusters=n_clusters)
idx = clf.fit_predict(word_vectors)
# Out:
# Wall time: 10min 32s

# %% [markdown]
# Examine the words in 10 clusters.

# %%
model_vocab = np.array(list(model.wv.vocab.keys()))
for i in range(10):
    print(model_vocab[idx == i])
# Out:
# ['just' 'because']
# ['mm' 'pong' 'tod' 'della']
# ['outings']
# ['pirates' 'favourites' 'acceptance' 'shenanigans']
# ['underworld' 'complained' 'complicated' 'slick' 'drew' 'ferrell' 'wasps'
#  'braindead' 'ancestor']
# ['stuck' 'history' 'lesbian' 'rush' 'sequels' 'mentally' 'refugee' 'nell'
#  'arresting' 'sirk']
# ['commits' 'rescues' 'jacobi']
# ['judy' 'cream' 'wayans' 'revolve' 'maniacs' 'maestro' 'ammo']
# ['precision' 'richness' 'seductress' 'indigo']
# ['pleasure' 'leave']

# %% [markdown]
# Create a dictionary where the keys are the words in the `word2vec` vocabulary, and the values are the cluster indices of those words.

# %%
cluster_mapping = dict(zip(model_vocab, idx))
cluster_mapping
# Out:
# {'with': 700,
#  'all': 1207,
#  'this': 1114,
#  'stuff': 2490,
#  'going': 2896,
#  'down': 2573,
#  'at': 2801,
#  'the': 1214,
#  'moment': 697,
#  'mj': 2801,
#  'i': 1014,
#  've': 2967,
#  'started': 1360,
#  'listening': 1540,
#  'to': 1952,
#  'his': 2003,
#  'music': 1537,
#  'watching': 145,
#  'odd': 1537,
#  'documentary': 355,
#  'here': 452,
#  'and': 747,
#  'there': 2957,
#  'watched': 1553,
#  'again': 693,
#  'maybe': 825,
#  'just': 0,
#  'want': 2778,
#  'get': 2222,
#  'a': 2394,
#  'certain': 2543,
#  'insight': 995,
#  'into': 2567,
#  'guy': 1660,
#  'who': 1557,
#  'thought': 1927,
#  'was': 2699,
#  'really': 1838,
#  'cool': 2545,
#  'in': 825,
#  'eighties': 2894,
#  'make': 340,
#  'up': 2985,
#  'my': 1772,
#  'mind': 2681,
#  'whether': 2097,
#  'he': 562,
#  'is': 826,
#  'guilty': 1650,
#  'or': 1810,
#  'innocent': 244,
#  'part': 891,
#  'biography': 1902,
#  'feature': 1553,
#  'film': 648,
#  'which': 1891,
#  'remember': 2412,
#  'see': 2055,
#  'cinema': 2904,
#  'when': 1627,
#  'it': 1014,
#  'originally': 1651,
#  'released': 257,
#  'some': 2043,
#  'of': 340,
#  'has': 175,
#  'subtle': 2681,
#  'messages': 693,
#  'about': 1779,
#  's': 995,
#  'feeling': 1046,
#  'towards': 2635,
#  'press': 2418,
#  'also': 2086,
#  'obvious': 1041,
#  'message': 409,
#  'drugs': 1145,
#  'are': 1617,
#  'bad': 1772,
#  'm': 2727,
#  'kay': 307,
#  'visually': 2057,
#  'impressive': 516,
#  'but': 2254,
#  'course': 3215,
#  'michael': 1553,
#  'jackson': 562,
#  'so': 1642,
#  'unless': 773,
#  'you': 1651,
#  'remotely': 1515,
#  'like': 1622,
#  'anyway': 2569,
#  'then': 1998,
#  'hate': 2468,
#  'find': 231,
#  'boring': 2699,
#  'may': 217,
#  'call': 1317,
#  'an': 671,
#  'for': 1237,
#  'making': 685,
#  'movie': 2177,
#  'most': 217,
#  'fans': 1408,
#  'would': 359,
#  'say': 1041,
#  'that': 2678,
#  'made': 2358,
#  'if': 2981,
#  'true': 2082,
#  'nice': 224,
#  'him': 2300,
#  'actual': 1935,
#  'bit': 3024,
#  'finally': 3109,
#  'starts': 1642,
#  'only': 2741,
#  'on': 2009,
#  '20': 647,
#  'minutes': 175,
#  'excluding': 753,
#  'smooth': 2622,
#  'criminal': 2741,
#  'sequence': 1108,
#  'joe': 2250,
#  'pesci': 355,
#  'convincing': 2007,
#  'as': 3123,
#  'psychopathic': 2881,
#  'powerful': 1294,
#  'drug': 3108,
#  'lord': 862,
#  'why': 562,
#  'wants': 1439,
#  'dead': 1494,
#  'beyond': 922,
#  'me': 626,
#  'because': 0,
#  'plans': 519,
#  'nah': 2904,
#  'character': 3240,
#  'wanted': 281,
#  'people': 1023,
#  'know': 2987,
#  'etc': 1294,
#  'dunno': 2181,
#  'hates': 693,
#  'lots': 2049,
#  'things': 773,
#  'turning': 2146,
#  'car': 145,
#  'robot': 2206,
#  'whole': 2132,
#  'speed': 1363,
#  'demon': 245,
#  'director': 1580,
#  'must': 773,
#  'have': 2190,
#  'had': 1765,
#  'patience': 922,
#  'saint': 3276,
#  'came': 2258,
#  'filming': 340,
#  'usually': 3102,
#  'directors': 1106,
#  'working': 1893,
#  'one': 983,
#  'kid': 201,
#  'let': 2015,
#  'alone': 399,
#  'bunch': 1558,
#  'them': 710,
#  'performing': 2111,
#  'complex': 568,
#  'dance': 1058,
#  'scene': 1749,
#  'bottom': 515,
#  'line': 2862,
#  'level': 3341,
#  'another': 1902,
#  'think': 931,
#  'not': 1196,
#  'stay': 1666,
#  'away': 1902,
#  'does': 1310,
#  'try': 431,
#  'give': 2079,
#  'off': 2546,
#  'wholesome': 1062,
#  'ironically': 145,
#  'buddy': 2081,
#  'girl': 449,
#  'truly': 1577,
#  'talented': 1222,
#  'ever': 2177,
#  'grace': 858,
#  'planet': 1496,
#  'well': 570,
#  'attention': 3316,
#  'gave': 1790,
#  'subject': 2054,
#  'hmmm': 2904,
#  'don': 2904,
#  't': 2156,
#  'can': 2904,
#  'be': 2627,
#  'different': 1975,
#  'behind': 719,
#  'closed': 2477,
#  'doors': 255,
#  'fact': 1048,
#  'either': 1600,
#  'extremely': 202,
#  'stupid': 2088,
#  'hope': 1775,
#  'latter': 2556,
#  'classic': 1041,
#  'war': 2851,
#  'worlds': 2303,
#  'by': 2672,
#  'timothy': 437,
#  'hines': 1151,
#  'very': 3222,
#  'entertaining': 2334,
#  'obviously': 2333,
#  'goes': 993,
#  'great': 554,
#  'effort': 1055,
#  'lengths': 2315,
#  'faithfully': 1205,
#  'recreate': 1337,
#  'h': 1515,
#  'g': 516,
#  'wells': 716,
#  'book': 2904,
#  'mr': 3109,
#  'succeeds': 922,
#  'doing': 1160,
#  'those': 1866,
#  'appreciated': 521,
#  'standard': 519,
#  'predictable': 1108,
#  'hollywood': 433,
#  'fare': 1425,
#  'comes': 611,
#  'out': 881,
#  'every': 244,
#  'year': 262,
#  'e': 940,
#  'spielberg': 916,
#  'version': 1143,
#  'tom': 234,
#  'cruise': 3114,
#  'slightest': 1775,
#  'resemblance': 2153,
#  'everyone': 2681,
#  'looks': 1334,
#  'themselves': 261,
#  'amateur': 2684,
#  'critics': 983,
#  'look': 2177,
#  'criticize': 1339,
#  'everything': 145,
#  'they': 2791,
#  'others': 2645,
#  'rate': 255,
#  'more': 2312,
#  'important': 2116,
#  'bases': 255,
#  'being': 2301,
#  'entertained': 521,
#  'never': 1994,
#  'agree': 1110,
#  'we': 2166,
#  'enjoyed': 1408,
#  'put': 698,
#  'faithful': 627,
#  'novel': 2413,
#  'found': 2145,
#  'easy': 1998,
#  'overlook': 2799,
#  'what': 2083,
#  'perceive': 1584,
#  'its': 368,
#  'shortcomings': 1143,
#  'manager': 587,
#  'nicholas': 2051,
#  'bell': 446,
#  'giving': 202,
#  'welcome': 692,
#  'investors': 1282,
#  'robert': 1296,
#  'carradine': 1585,
#  'primal': 1769,
#  'park': 2799,
#  'secret': 2104,
#  'project': 2772,
#  'animal': 1198,
#  'using': 1460,
#  'dna': 1123,
#  'scientists': 1082,
#  'resurrect': 1089,
#  'nature': 2030,
#  'predators': 1458,
#  'tiger': 1593,
#  'scientific': 2838,
#  'ambition': 1775,
#  'turns': 1020,
#  'deadly': 515,
#  'however': 1893,
#  'high': 868,
#  'fence': 1553,
#  'opened': 2361,
#  'creature': 3065,
#  'escape': 2594,
#  'begins': 2049,
#  'stalking': 1893,
#  'prey': 842,
#  'human': 166,
#  'visitors': 2020,
#  'tourists': 2053,
#  'meanwhile': 1699,
#  'youngsters': 2822,
#  'enter': 942,
#  'restricted': 2254,
#  'area': 1918,
#  'security': 143,
#  'center': 2024,
#  'attacked': 1697,
#  'pack': 1817,
#  'large': 2575,
#  'pre': 2349,
#  'historical': 1095,
#  'animals': 244,
#  'bigger': 1361,
#  'addition': 1141,
#  'agent': 618,
#  'stacy': 2086,
#  'her': 2378,
#  'mate': 723,
#  'brian': 1697,
#  'fight': 2305,
#  'hardly': 1914,
#  'against': 2219,
#  'real': 3048,
#  'star': 2059,
#  'stars': 3109,
#  'astounding': 3297,
#  'though': 848,
#  'giant': 1888,
#  'group': 798,
#  'run': 1833,
#  'afoul': 1851,
#  'furthermore': 381,
#  'third': 2156,
#  'dangerous': 2024,
#  'slow': 1106,
#  'stalks': 2601,
#  'victims': 189,
#  'delivers': 1562,
#  'goods': 909,
#  'blood': 1558,
#  'gore': 993,
#  'hair': 931,
#  'raising': 1362,
#  'chills': 772,
#  'full': 2433,
#  'scares': 714,
#  'appear': 2735,
#  'mediocre': 1768,
#  'special': 3317,
#  'effects': 521,
#  'story': 265,
#  'provides': 2086,
#  'exciting': 921,
#  'stirring': 710,
#  'entertainment': 627,
#  'results': 878,
#  'quite': 451,
#  'majority': 2177,
#  'computer': 1041,
#  'generator': 1532,
#  'seem': 1235,
#  'totally': 255,
#  'lousy': 773,
#  'performances': 451,
#  'players': 2062,
#  'reacting': 2086,
#  'appropriately': 184,
#  'becoming': 2927,
#  'food': 1701,
#  'actors': 2929,
#  'physical': 1143,
#  'beasts': 1622,
#  'running': 716,
#  'bound': 307,
#  'leaps': 2727,
#  'dangling': 2361,
#  'over': 1690,
#  'walls': 1108,
#  'packs': 2286,
#  'ridiculous': 1555,
#  'final': 221,
#  'no': 2328,
#  'small': 2662,
#  'kids': 944,
#  'realistic': 3059,
#  'gory': 1210,
#  'violent': 339,
#  'attack': 307,
#  'scenes': 3080,
#  'other': 2691,
#  'films': 881,
#  'following': 1532,
#  '2002': 3051,
#  'james': 1701,
#  'r': 2778,
#  'vanessa': 449,
#  'angel': 773,
#  'david': 1300,
#  'keith': 1784,
#  'john': 909,
#  'rhys': 99,
#  'davies': 868,
#  'much': 2286,
#  'better': 2848,
#  '10': 3102,
#  '000': 1537,
#  '2006': 904,
#  'roland': 837,
#  'steven': 575,
#  'cliff': 2685,
#  'curtis': 3320,
#  'camilla': 3051,
#  'belle': 271,
#  'motion': 433,
#  'picture': 683,
#  'filled': 2678,
#  'bloody': 2496,
#  'moments': 352,
#  'badly': 2556,
#  'directed': 322,
#  'george': 2080,
#  'miller': 143,
#  'originality': 2387,
#  'takes': 455,
#  'too': 1954,
#  'many': 1182,
#  'elements': 336,
#  'from': 1935,
#  'previous': 1221,
#  'australian': 2671,
#  'television': 1265,
#  'wave': 1790,
#  'journey': 758,
#  'earth': 1893,
#  'occasionally': 579,
#  'man': 860,
#  'snowy': 1309,
#  'river': 913,
#  'robinson': 1527,
#  'crusoe': 823,
#  'rating': 2079,
#  'below': 1893,
#  'average': 2770,
#  'barrel': 1360,
#  'assumed': 848,
#  'praised': 1550,
#  'greatest': 771,
#  'filmed': 2104,
#  'opera': 99,
#  'didn': 1361,
#  'read': 1331,
#  'somewhere': 1904,
#  'care': 2421,
#  'wagner': 137,
#  'anything': 1165,
#  'except': 1828,
#  'their': 2177,
#  'desire': 307,
#  'cultured': 481,
#  'representation': 520,
#  'swan': 2073,
#  'song': 731,
#  'strikes': 1537,
#  'disaster': 1089,
#  'leaden': 2689,
#  'reading': 2951,
#  'score': 1129,
#  'matched': 997,
#  'text': 1465,
#  'questionable': 838,
#  'ideas': 1667,
#  'matter': 1044,
#  'play': 978,
#  'especially': 3261,
#  'shakespeare': 2086,
#  'should': 2339,
#  'allowed': 712,
#  'anywhere': 1857,
#  'near': 2687,
#  'theatre': 336,
#  'studio': 515,
#  'without': 1288,
#  'smallest': 1651,
#  'justification': 1840,
#  'decided': 99,
#  'bisexual': 1934,
#  'title': 243,
#  'stages': 710,
#  'kind': 2610,
#  'babe': 1257,
#  'continues': 2557,
#  'sing': 2177,
#  'tenor': 2193,
#  'few': 1814,
#  'any': 197,
#  'singers': 878,
#  'double': 1054,
#  'dose': 1735,
#  'jordan': 1993,
#  'conductor': 1667,
#  'seen': 937,
#  'face': 1650,
#  'heard': 2862,
#  'voice': 570,
#  'appears': 1615,
#  'exposure': 1845,
#  'ate': 433,
#  'during': 1821,
#  'playing': 1209,
#  'good': 1021,
#  'friday': 1380,
#  'way': 758,
#  'represented': 232,
#  'stuck': 5,
#  'ill': 1889,
#  'laid': 307,
#  'turf': 2230,
#  'sometimes': 1859,
#  'piece': 1210,
#  'such': 554,
#  'our': 1668,
#  'thoughts': 3229,
#  'couldn': 1857,
#  'mountain': 1576,
#  'lush': 428,
#  'provided': 685,
#  'julie': 1624,
#  'andrews': 596,
#  'sound': 1205,
#  'hard': 412,
#  'endure': 2981,
#  'voices': 255,
#  'particular': 719,
#  'possessing': 1192,
#  'adds': 637,
#  'sort': 1198,
#  'uninspired': 428,
#  'conducting': 885,
#  'unfolding': 1062,
#  'ritual': 2042,
#  'someone': 2144,
#  'review': 878,
#  'mentioned': 2665,
#  '1951': 329,
#  'recording': 1320,
#  'often': 773,
#  'altogether': 1603,
#  'lacks': 855,
#  'sense': 875,
#  'pulse': 2804,
#  'flow': 786,
#  'after': 1989,
#  'half': 2769,
#  'century': 578,
#  'orchestral': 2334,
#  'set': 307,
#  'modern': 2145,
#  'still': 2726,
#  'superior': 523,
#  'superbly': 2193,
#  'trashy': 2230,
#  'unpretentious': 868,
#  '80': 813,
#  'exploitation': 1021,
#  'hooray': 525,
#  'credits': 2958,
#  'opening': 977,
#  'sequences': 3043,
#  'somewhat': 1609,
#  'false': 520,
#  'impression': 618,
#  're': 658,
#  'dealing': 1705,
#  'serious': 1867,
#  'harrowing': 448,
#  'drama': 446,
#  'need': 1810,
#  'fear': 550,
#  'barely': 1739,
#  'ten': 1282,
#  'later': 1020,
#  'until': 1217,
#  'necks': 3344,
#  'nonsensical': 2186,
#  'chainsaw': 245,
#  'battles': 2278,
#  'rough': 2886,
#  'fist': 318,
#  'fights': 1666,
#  'lurid': 225,
#  'dialogs': 1479,
#  'gratuitous': 1732,
#  'nudity': 3223,
#  'bo': 1727,
#  'ingrid': 169,
#  'two': 2837,
#  'orphaned': 1645,
#  'siblings': 1278,
#  'unusually': 1537,
#  'close': 312,
#  'even': 2332,
#  'slightly': 3235,
#  'perverted': 1697,
#  'relationship': 1058,
#  'imagine': 3081,
#  'ripping': 750,
#  'towel': 1902,
#  'covers': 261,
#  'your': 2197,
#  'sister': 963,
#  'naked': 831,
#  'body': 2726,
#  'stare': 2606,
#  'genitals': 2654,
#  'several': 1558,
#  'judging': 1154,
#  'dubbed': 265,
#  'laughter': 680,
#  'she': 2074,
#  'doesn': 924,
#  'sick': 854,
#  'dude': 1350,
#  'fled': 508,
#  'russia': 1100,
#  'parents': 1179,
#  'nasty': 761,
#  'soldiers': 818,
#  'brutally': 2006,
#  'slaughtered': 3214,
#  'mommy': 1649,
#  'daddy': 3107,
#  'friendly': 2295,
#  'took': 1609,
#  'custody': 810,
#  'raised': 800,
#  'trained': 1054,
#  'expert': 1241,
#  'plot': 1585,
#  'lifts': 1040,
#  'years': 2541,
#  'facing': 1408,
#  'ultimate': 2203,
#  'quest': 2329,
#  'mythical': 916,
#  'incredibly': 380,
#  'valuable': 1273,
#  'white': 2257,
#  'fire': 2237,
#  'diamond': 3170,
#  'coincidentally': 3156,
#  'mine': 858,
#  'life': 271,
#  'little': 2734,
#  'narrative': 369,
#  'structure': 1439,
#  'sure': 1315,
#  'lot': 2464,
#  'fun': 323,
#  'watch': 906,
#  'time': 1698,
#  'clue': 1889,
#  'beating': 462,
#  'cause': 997,
#  'bet': 2406,
#  'understood': 14,
#  'less': 175,
#  'whatever': 1787,
#  'violence': 739,
#  'magnificently': 2771,
#  'grotesque': 885,
#  'single': 2405,
#  'twist': 106,
#  'retarded': 2116,
#  'script': 696,
#  'bonkers': 579,
#  'repair': 1893,
#  'suddenly': 523,
#  'won': 1977,
#  'reveal': 1893,
#  'reason': 106,
#  'needs': 241,
#  'replacement': 349,
#  'fred': 2370,
#  'williamson': 1144,
#  'enters': 202,
#  'big': 2050,
#  'cigar': 746,
#  'mouth': 2620,
#  'sleazy': 1581,
#  'black': 1324,
#  'fingers': 2881,
#  'local': 747,
#  'prostitutes': 658,
#  'principal': 1416,
#  'opponent': 429,
#  'italian': 1425,
#  'chick': 3015,
#  'breasts': 570,
#  'hideous': 1422,
#  'accent': 358,
#  'preposterous': 1007,
#  'catchy': 2358,
#  'theme': 806,
#  'plays': 2445,
#  'least': 786,
#  'dozen': 271,
#  'times': 764,
#  'throughout': 3311,
#  'obligatory': 2697,
#  'falling': 929,
#  'love': 3227,
#  'montage': 193,
#  'loads': 254,
#  'attractions': 411,
#  'god': 1930,
#  'brilliant': 2521,
#  'experience': 826,
#  'original': 2733,
#  'french': 237,
#  'translates': 1380,
#  'itself': 881,
#  'survive': 2687,
#  'uniquely': 3018,
#  'appropriate': 2662,
#  'makes': 2302,
#  'rest': 492,
#  'none': 666,
#  'dont': 2786,
#  'got': 662,
#  'pretty': 2877,
#  'action': 2903,
#  'change': 531,
#  'location': 2466,
#  'harry': 2822,
#  'hurt': 658,
#  'offensive': 1784,
#  'eastwood': 3142,
#  'form': 2109,
#  'dirty': 2303,
#  'liked': 2147,
#  'pat': 1169,
#  'town': 417,
#  'cop': 1563,
#  'than': 257,
#  'pool': 2788,
#  '4': 1888,
#  '5': 1671,
#  'could': 508,
#  'been': 2059,
#  'short': 1962,
#  'cheesy': 169,
#  'acting': 2095,
#  'looked': 809,
#  'past': 515,
#  'wasn': 1062,
#  'background': 2867,
#  'centers': 2024,
#  'around': 1129,
#  'evil': 1422,
#  'witch': 554,
#  'linked': 3238,
#  'woman': 2145,
#  'gets': 409,
#  'drags': 1988,
#  'clearly': 2084,
#  'explains': 976,
#  'keeps': 1235,
#  'plodding': 649,
#  'christopher': 1893,
#  'walken': 2672,
#  'completely': 2253,
#  'senseless': 848,
#  'potential': 825,
#  'tv': 599,
#  'avoid': 2889,
#  'video': 2193,
#  'friend': 405,
#  'house': 1994,
#  'glad': 87,
#  'did': 257,
#  'waste': 868,
#  'money': 349,
#  'buying': 90,
#  'cover': 2397,
#  '1975': 2220,
#  'clips': 2334,
#  'rocket': 1590,
#  'blow': 1704,
#  'ups': 1108,
#  'related': 3268,
#  'flight': 3022,
#  'smoking': 1439,
#  'gun': 2049,
#  'clip': 307,
#  'astronauts': 436,
#  'preparing': 2159,
#  'broadcast': 2458,
#  'edits': 389,
#  'own': 2075,
#  'instead': 359,
#  'letting': 2304,
#  'us': 2489,
#  'listen': 813,
#  'crew': 2400,
#  'curiously': 453,
#  'ends': 562,
#  'showing': 1872,
#  'claims': 2555,
#  'radiation': 599,
#  'photography': 1224,
#  'lead': 626,
#  'believe': 453,
#  'ignorant': 1760,
#  'ax': 2310,
#  'grind': 201,
#  'nasa': 2020,
#  'american': 265,
#  'general': 2075,
#  'science': 790,
#  'bought': 1467,
#  '1': 1878,
#  'grossly': 2344,
#  'despite': 1159,
#  'featuring': 1779,
#  'names': 1467,
#  'adam': 2445,
#  'sandler': 698,
#  'billy': 1144,
#  'bob': 1049,
#  'thornton': 1412,
#  'burt': 2531,
#  'young': 2058,
#  'funny': 1735,
#  'taking': 410,
#  'straight': 2616,
#  'through': 481,
#  'uses': 3048,
#  'tired': 3031,
#  'comedic': 207,
#  'techniques': 2722,
#  'consistently': 57,
#  'breaking': 1642,
#  'fourth': 1415,
#  'wall': 2690,
#  'talks': 3343,
#  'audience': 2021,
#  'seemingly': 842,
#  'pointless': 3311,
#  'montages': 1370,
#  'hot': 3227,
#  'girls': 848,
#  'waiter': 3222,
#  'ship': 1362,
#  'successful': 805,
#  'comedian': 823,
#  'order': 1525,
#  'become': 2631,
#  'women': 1517,
#  'resident': 1360,
#  'shamelessly': 2612,
#  'named': 3041,
#  'due': 2057,
#  'unfathomable': 1694,
#  'success': 1238,
#  'opposite': 1697,
#  'gender': 597,
#  'presumed': 1618,
#  'lost': 66,
#  'sea': 3035,
#  'break': 1944,
#  'rather': 3038,
#  'locked': 3218,
#  'bathroom': 944,
#  'presumably': 2277,
#  'perhaps': 1579,
#  'worst': 3158,
#  'references': 2057,
#  'mad': 482,
#  'max': 1241,
#  'ii': 2010,
#  'wild': 345,
#  'clear': 607,
#  'reference': 1974,
#  'tribute': 2557,
#  'peter': 327,
#  'lorre': 1793,
#  'masterpiece': 970,
#  'll': 904,
#  'talk': 1116,
#  'future': 507,
#  'happens': 1660,
#  'army': 936,
#  'eastern': 1776,
#  'european': 816,
#  'gather': 1784,
#  'forces': 2218,
#  'south': 2558,
#  'border': 2116,
#  'gary': 79,
#  'busey': 2097,
#  'kicks': 474,
#  'butts': 1735,
#  'laughable': 931,
#  'example': 1235,
#  'reagan': 1646,
#  'era': 665,
#  'cultural': 758,
#  'wastes': 684,
#  'decent': 380,
#  'supporting': 2335,
#  'cast': 1779,
#  'headed': 1217,
#  'l': 414,
#  'q': 336,
#  'jones': 2531,
#  'although': 1212,
#  'generally': 2240,
#  'do': 411,
#  'remakes': 2944,
#  'believing': 2991,
#  'exception': 106,
#  'actually': 1593,
#  'far': 2301,
#  'comment': 1561,
#  'remake': 868,
#  'opinion': 561,
#  'purely': 523,
#  'comparison': 1851,
#  'written': 2023,
#  'question': 307,
#  'capote': 1685,
#  'words': 3018,
#  'anthony': 1339,
#  'edwards': 1028,
#  'eric': 2074,
#  'roberts': 2034,
#  'superb': 658,
#  'movies': 616,
#  'each': 826,
#  'case': 980,
#  'always': 2483,
#  'wondered': 1993,
#  'number': 703,
#  'famous': 2445,
#  'brother': 680,
#  'certainty': 1764,
#  'top': 349,
#  'profession': 712,
#  'recommend': 714,
#  '50': 1464,
#  'keep': 1902,
#  'dvd': 141,
#  'shelves': 685,
#  'harvey': 3037,
#  'lights': 2850,
#  'candle': 549,
#  'performance': 3086,
#  'spall': 2795,
#  'while': 1265,
#  'predict': 1084,
#  'titular': 838,
#  'tight': 3261,
#  'teacher': 1834,
#  'will': 2237,
#  'catharsis': 1296,
#  'based': 3037,
#  'deep': 321,
#  'how': 1098,
#  'emotions': 1494,
#  'surprising': 2337,
#  'range': 1986,
#  'feelings': 389,
#  'conveyed': 1311,
#  'moving': 2569,
#  'portray': 854,
#  'mike': 865,
#  'leigh': 3102,
#  ...}

# %%
def review_centroid_vec(review):
    centroid_counts = np.zeros([len(cluster_mapping)])
    for sentence in review_to_sentences(review, remove_stopwords=True):
        for word in sentence:
            if word in cluster_mapping:
                centroid_counts[cluster_mapping[word]] += 1
    return centroid_counts

# %%
train_vecs = np.stack([review_centroid_vec(review) for review in tqdm(df_labeled_train['review'])])
test_vecs = np.stack([review_centroid_vec(review) for review in tqdm(df_test['review'])])
# Out:
#   0%|                                                                                        | 0/25000 [00:00<?, ?it/s]Exception ignored in: <bound method tqdm.__del__ of   0%|                                                                                        | 0/25000 [01:35<?, ?it/s]>
# Traceback (most recent call last):
#   File "d:\program files\python36\lib\site-packages\tqdm\_tqdm.py", line 879, in __del__
#     self.close()
#   File "d:\program files\python36\lib\site-packages\tqdm\_tqdm.py", line 1098, in close
#     self._decr_instances(self)
#   File "d:\program files\python36\lib\site-packages\tqdm\_tqdm.py", line 438, in _decr_instances
#     cls._instances.remove(instance)
#   File "d:\program files\python36\lib\_weakrefset.py", line 109, in remove
#     self.data.remove(ref(item))
# KeyError: <weakref at 0x000002238E7926D8; to 'tqdm' at 0x000002238245B780>
#
#
#   0%|                                                                              | 32/25000 [00:00<01:18, 316.24it/s]
#
#   0%|▎                                                                             | 91/25000 [00:00<00:55, 450.78it/s]
#
#   1%|▍                                                                            | 152/25000 [00:00<00:49, 501.53it/s]
#
#   1%|▋                                                                            | 205/25000 [00:00<00:49, 505.85it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#
#
#   1%|▊                                                                            | 256/25000 [00:00<00:49, 496.73it/s]
#
#   1%|▉                                                                            | 309/25000 [00:00<00:49, 502.41it/s]
#
#   1%|█▏                                                                           | 368/25000 [00:00<00:47, 514.14it/s]
#
#   2%|█▎                                                                           | 423/25000 [00:00<00:47, 518.37it/s]
#
#   2%|█▍                                                                           | 475/25000 [00:00<00:47, 515.37it/s]
#
#   2%|█▋                                                                           | 531/25000 [00:01<00:47, 516.39it/s]
#
#   2%|█▊                                                                           | 583/25000 [00:01<00:48, 502.48it/s]
#
#   3%|█▉                                                                           | 631/25000 [00:01<00:48, 498.91it/s]
#
#   3%|██                                                                           | 687/25000 [00:01<00:48, 503.31it/s]
#
#   3%|██▎                                                                          | 737/25000 [00:01<00:48, 502.51it/s]
#
#   3%|██▍                                                                          | 789/25000 [00:01<00:48, 503.57it/s]
#
#   3%|██▌                                                                          | 841/25000 [00:01<00:47, 504.34it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
/s]
#
#  98%|█████████████████████████████████████████████████████████████████████████▎ | 24425/25000 [00:50<00:01, 482.49it/s]
#
#  98%|█████████████████████████████████████████████████████████████████████████▍ | 24472/25000 [00:50<00:01, 482.44it/s]
#
#  98%|█████████████████████████████████████████████████████████████████████████▌ | 24522/25000 [00:50<00:00, 482.46it/s]
#
#  98%|█████████████████████████████████████████████████████████████████████████▋ | 24570/25000 [00:50<00:00, 482.43it/s]
#
#  99%|█████████████████████████████████████████████████████████████████████████▉ | 24626/25000 [00:51<00:00, 482.54it/s]
#
#  99%|██████████████████████████████████████████████████████████████████████████ | 24682/25000 [00:51<00:00, 482.66it/s]
#
#  99%|██████████████████████████████████████████████████████████████████████████▏| 24736/25000 [00:51<00:00, 482.76it/s]
#
#  99%|██████████████████████████████████████████████████████████████████████████▎| 24788/25000 [00:51<00:00, 482.68it/s]
#
#  99%|██████████████████████████████████████████████████████████████████████████▌| 24838/25000 [00:51<00:00, 482.70it/s]
#
# 100%|██████████████████████████████████████████████████████████████████████████▋| 24894/25000 [00:51<00:00, 482.85it/s]
#
# 100%|██████████████████████████████████████████████████████████████████████████▊| 24946/25000 [00:51<00:00, 482.89it/s]
#
# 100%|██████████████████████████████████████████████████████████████████████████▉| 24998/25000 [00:51<00:00, 482.91it/s]
#
#  20%|███████████████▎                                                            | 5032/25000 [00:10<00:41, 479.51it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
#  28%|█████████████████████▎                                                      | 7024/25000 [00:14<00:37, 481.77it/s]d:\program files\python36\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'....................................................................'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 100%|███████████████████████████████████████████████████████████████████████████| 25000/25000 [00:52<00:00, 480.00it/s]

# %% [markdown]
# ### Random forest classifier

# %%
# %%time
clf = RandomForestClassifier(n_estimators=100)
clf.fit(train_vecs, df_labeled_train['sentiment'])
# Out:
# Wall time: 2min 25s

# %%
# %%time
pred = clf.predict(test_vecs)
# Out:
# Wall time: 4.1 s

# %%
output = pd.DataFrame({'id': df_test['id'], 'sentiment': pred})
output
# Out:
#              id  sentiment
# 0      12311_10          1
# 1        8348_2          0
# 2        5828_4          0
# 3        7186_2          0
# 4       12128_7          1
# 5        2913_8          1
# 6        4396_1          0
# 7         395_2          0
# 8       10616_1          0
# 9        9074_9          1
# 10       9252_3          1
# 11       9896_9          0
# 12        574_4          1
# 13      11182_8          1
# 14      11656_4          0
# 15       2322_4          1
# 16       8703_1          1
# 17       7483_1          0
# 18      6007_10          1
# 19      12424_4          0
# 20       4672_1          0
# 21      10841_3          0
# 22       8954_7          1
# 23       7392_1          0
# 24      10288_8          0
# 25       5343_4          0
# 26       4950_1          0
# 27       9257_4          0
# 28       8689_3          0
# 29       4480_2          0
# ...         ...        ...
# 24970   6857_10          1
# 24971   11091_8          1
# 24972    4167_2          0
# 24973     679_4          0
# 24974   10147_1          0
# 24975    6875_1          0
# 24976    923_10          1
# 24977    6200_8          0
# 24978    7208_8          1
# 24979    5363_8          1
# 24980    4067_8          1
# 24981    1773_7          1
# 24982   1498_10          1
# 24983  10497_10          0
# 24984   3444_10          1
# 24985     588_2          0
# 24986    9678_9          1
# 24987    1983_9          0
# 24988    5012_3          0
# 24989   12240_2          1
# 24990    5071_2          0
# 24991    5078_2          0
# 24992   10069_3          1
# 24993    7407_8          1
# 24994    7207_1          0
# 24995   2155_10          1
# 24996     59_10          1
# 24997    2531_1          1
# 24998    7772_8          1
# 24999  11465_10          0
#
# [25000 rows x 2 columns]

# %%
output.to_csv('submission/word2vec_cluster_randomforest.csv', index=False)
